# %%
# Użycie zapisanych na dysku zdjęć.
# !unzip -q '/content/drive/My Drive/train_val_test.zip' -d '/content'
# Load the TensorBoard notebook extension. #%reload_ext tensorboard
# %load_ext tensorboard
# Out:
# train_val_test/train/type_S/0A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/0A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/0lE — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/0lE тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1000A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1000A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1002A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1002A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1003A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1003A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1005A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1005A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1006A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1006A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1007A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1007A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1008A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1008A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1009A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1009A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/100A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/100A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/100lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/100lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/100lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/100lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1010A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1010A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1011A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1011A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1012A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1012A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1013A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1013A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1014A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1014A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1015A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1015A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1017A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1017A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1018A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1018A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/101lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/101lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1020A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1020A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1021A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1021A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1022A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1022A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1026A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1026A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1027A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1027A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/102lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/102lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1032A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1032A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1033A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1033A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1034A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1034A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1039A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1039A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/103A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/103A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/103lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/103lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1040A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1040A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1043A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1043A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1045A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1045A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1047A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1047A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1049A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1049A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1050A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1050A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1051A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1051A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1052A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1052A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1053A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1053A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1054A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1054A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/105lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/105lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1061A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1061A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1062A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1062A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1063A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1063A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1065A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1065A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1066A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1066A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/106lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/106lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/106lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/106lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1071A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1071A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1072A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1072A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1076A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1076A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1077A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1077A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/107A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/107A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/107lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/107lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1082A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1082A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1085A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1085A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1086A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1086A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1088A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1088A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1089A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1089A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/108A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/108A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/108lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/108lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/108lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/108lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1090A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1090A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1093A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1093A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1095A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1095A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1096A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1096A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/109lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/109lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/10J — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/10J тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/10lE — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/10lE тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/10lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/10lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1100A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1100A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1101A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1101A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1102A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1102A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1104A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1104A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1105A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1105A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1106A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1106A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1107A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1107A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1109A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1109A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/110A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/110A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/110lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/110lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/110lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/110lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1110A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1110A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1112A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1112A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1115A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1115A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1118A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1118A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1119A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1119A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/111A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/111A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/111lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/111lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1120A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1120A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1121A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1121A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1123A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1123A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1124A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1124A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1125A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1125A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1129A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1129A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/112A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/112A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/112lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/112lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1132A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1132A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1134A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1134A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1135A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1135A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1136A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1136A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1139A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1139A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/113A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/113A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1140A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1140A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1143A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1143A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1144A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1144A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1149A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1149A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/114A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/114A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/114lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/114lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1150A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1150A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1151A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1151A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1152A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1152A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1155A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1155A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1157A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1157A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1158A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1158A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/115A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/115A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/115lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/115lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/115lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/115lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1161A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1161A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1163A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1163A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1164A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1164A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1166A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1166A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1167A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1167A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1168A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1168A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/116A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/116A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/116lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/116lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1170A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1170A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1171A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1171A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1172A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1172A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1173A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1173A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1178A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1178A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/117A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/117A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/117lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/117lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/117lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/117lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1180A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1180A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1181A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1181A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1184A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1184A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1187A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1187A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1188A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1188A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/118lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/118lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/118lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/118lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1190A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1190A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1191A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1191A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1193A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1193A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1195A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1195A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1196A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1196A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1199A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1199A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/119A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/119A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/119lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/119lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/119lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/119lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/11A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/11A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/11J — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/11J тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/11lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/11lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/11lE — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/11lE тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1200A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1200A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1201A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1201A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1202A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1202A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1203A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1203A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1204A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1204A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1205A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1205A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1207A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1207A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1209A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1209A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/120A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/120A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/120lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/120lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1210A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1210A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1212A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1212A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1213A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1213A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1214A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1214A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1215A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1215A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1218A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1218A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/121A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/121A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/121lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/121lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1220A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1220A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1222A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1222A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1223A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1223A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1224A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1224A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1225A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1225A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1226A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1226A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1228A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1228A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1229A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1229A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/122lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/122lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/122lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/122lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1231A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1231A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1233A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1233A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1234A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1234A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1235A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1235A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1237A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1237A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1238A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1238A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/123A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/123A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/123lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/123lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1241A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1241A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1243A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1243A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1245A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1245A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1248A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1248A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/124A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/124A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/124lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/124lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1253A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1253A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1254A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1254A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1255A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1255A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1257A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1257A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1258A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1258A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1259A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1259A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1260A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1260A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1261A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1261A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1263A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1263A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1269A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1269A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/126lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/126lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/126lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/126lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1270A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1270A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1271A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1271A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1273A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1273A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1276A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1276A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1278A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1278A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1279A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1279A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/127A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/127A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/127lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/127lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1282A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1282A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1284A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1284A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1286A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1286A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1287A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1287A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1288A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1288A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1289A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1289A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/128A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/128A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1293A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1293A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1294A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1294A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1295A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1295A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1296A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1296A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1297A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1297A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1298A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1298A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1299A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1299A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/129A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/129A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/129lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/129lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/12A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/12A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/12lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/12lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/12lE — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/12lE тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/12lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/12lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1300A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1300A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1301A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1301A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1304A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1304A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1305A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1305A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1307A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1307A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1309A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1309A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1310A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1310A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1311A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1311A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1312A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1312A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1314A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1314A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1316A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1316A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1317A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1317A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/131lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/131lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1320A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1320A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1321A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1321A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1325A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1325A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1328A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1328A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/132lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/132lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1331A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1331A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1332A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1332A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1333A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1333A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1335A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1335A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1337A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1337A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1338A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1338A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/133lA — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/133lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/133lJ — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/133lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1340A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1340A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/train/type_S/1346A — kopia.png:  mismatching "local" filename (train_val_test/train/type_S/1346A тАФ kopia.png),
#          continuing with "central" filename version
# ...
# train_val_test/val/type_S/66A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/66A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/66lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/66lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/677A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/677A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/67lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/67lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/685A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/685A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/689A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/689A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/68lA — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/68lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/695A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/695A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/696A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/696A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/69J — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/69J тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/6J — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/6J тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/709A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/709A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/717A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/717A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/726A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/726A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/72A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/72A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/730A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/730A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/735A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/735A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/739A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/739A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/744A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/744A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/745A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/745A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/74lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/74lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/751A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/751A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/754A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/754A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/758A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/758A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/75A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/75A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/767A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/767A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/774A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/774A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/783A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/783A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/78lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/78lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/790A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/790A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/793A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/793A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/796A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/796A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/798A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/798A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/79lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/79lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/7A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/7A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/7lA — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/7lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/808A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/808A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/812A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/812A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/813A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/813A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/81lA — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/81lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/822A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/822A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/826A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/826A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/828A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/828A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/830A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/830A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/848A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/848A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/849A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/849A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/852A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/852A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/85lA — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/85lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/85lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/85lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/862A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/862A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/867A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/867A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/871A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/871A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/881A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/881A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/88lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/88lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/892A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/892A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/893A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/893A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/8A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/8A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/8lA — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/8lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/8lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/8lJ тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/900A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/900A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/906A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/906A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/90A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/90A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/913A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/913A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/914A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/914A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/918A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/918A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/91A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/91A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/920A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/920A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/925A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/925A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/926A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/926A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/927A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/927A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/933A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/933A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/936A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/936A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/939A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/939A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/947A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/947A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/94A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/94A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/952A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/952A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/956A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/956A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/958A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/958A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/95lA — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/95lA тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/963A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/963A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/967A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/967A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/982A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/982A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/986A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/986A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/989A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/989A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/990A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/990A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/991A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/991A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/995A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/995A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/997A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/997A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/999A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/999A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/99A — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/99A тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/9J — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/9J тАФ kopia.png),
#          continuing with "central" filename version
# train_val_test/val/type_S/9lJ — kopia.png:  mismatching "local" filename (train_val_test/val/type_S/9lJ тАФ kopia.png),
#          continuing with "central" filename version

# %%
from numpy.random import seed
seed(1)
from tensorflow.random import set_seed
set_seed(2)

import os
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report

from tensorflow.keras import applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from tensorflow.keras.optimizers import Adamax, Nadam
from tensorflow.keras.regularizers import l1_l2

BATCH_SIZE = 32
EPOCHS = 50
INITIAL_EPOCH = 0
IMG_HEIGHT, IMG_WIDTH, CHANNELS = 220, 220, 3

dir_path = "/content/train_val_test"
root = "/content/drive/My Drive/CNN_xception/" 

train_gen = ImageDataGenerator(rescale=1.0/255.)
val_gen = ImageDataGenerator(rescale=1.0/255.)
test_gen = ImageDataGenerator(rescale=1.0/255.)

train_generator = train_gen.flow_from_directory(
    dir_path + "/train",
    batch_size=BATCH_SIZE,
    shuffle=True,
    color_mode="rgb",
    class_mode="categorical",
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    seed=2)
validation_generator = val_gen.flow_from_directory(
    dir_path + "/val",
    batch_size=BATCH_SIZE,
    shuffle=True,
    color_mode="rgb",
    class_mode="categorical",
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    seed=2)
test_generator = test_gen.flow_from_directory(
    dir_path + "/test",
    batch_size=1,
    shuffle=False,
    color_mode="rgb",
    class_mode="categorical",
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    seed=2)

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size
STEP_SIZE_VALID = validation_generator.n // validation_generator.batch_size

my_callbacks = [
    ModelCheckpoint(filepath=root + "model.{epoch:02d}.h5",
                    monitor="val_accuracy",
                    mode="max",
                    save_best_only=True,
                    save_freq="epoch",),
    EarlyStopping(monitor="val_loss",
                  patience=5,),
    TensorBoard(log_dir=root + "logs",
                write_images=False,
                histogram_freq=1,
                embeddings_freq=2,),
]
# Out:
# Found 22461 images belonging to 5 classes.
# Found 7559 images belonging to 5 classes.
# Found 6221 images belonging to 5 classes.

# %%
# Użycie zapisanego na dysku modelu.
files = [f for f in sorted(os.listdir(root))]
model_file = files[-1]
INITIAL_EPOCH = int(model_file.split('.')[1])
EPOCHS += INITIAL_EPOCH
    
model = load_model(root + model_file)
print(f"Wczytanie pliku modelu: {model_file}, z ilością EPOCH: {INITIAL_EPOCH}")
# Out:
# Wczytanie pliku modelu: model.07.h5, z ilością EPOCH: 7

# %%
# Wczytanie modelu, ustawienie wag.
base_model = applications.Xception(weights="imagenet", 
                                   include_top=False, 
                                   pooling="avg",
                                   input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS))
# Zamrożenie części warstw by kożystać z wytrenowanych już wag.
trainable_layers = 100 # sieć ma jakoś 134 warstwy, 5 warst do wytrenowania to za mało
for i in range(len(base_model.layers) - trainable_layers):
    base_model.layers[i].trainable = False
    
# Dodanie warstwy do wczytanego modelu, uwzględnienie liczbę klas
x = base_model.output
predictions = Dense(5, activation="softmax")(x)
model = Model(inputs = base_model.input, outputs = predictions)

model.compile(optimizer=Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07), 
              loss="categorical_crossentropy", 
              metrics=["accuracy"])
model.summary()

# %%
# Wczytanie modelu i ustawienie parametrów by nadawał się do problemu.
model = applications.Xception(weights=None, 
                                   include_top=True, 
                                   pooling="avg",
                                   classes=5,
                                   classifier_activation="softmax",
                                   input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS))

model.compile(optimizer=Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07), 
              loss="categorical_crossentropy", 
              metrics=["accuracy"])
model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 220, 220, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 109, 109, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 109, 109, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 109, 109, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 107, 107, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 107, 107, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 107, 107, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 107, 107, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 107, 107, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 107, 107, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 107, 107, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 107, 107, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 54, 54, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 54, 54, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 54, 54, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 54, 54, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 54, 54, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 54, 54, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 54, 54, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 54, 54, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 54, 54, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 54, 54, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 27, 27, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 27, 27, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27, 27, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 27, 27, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 27, 27, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 27, 27, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 27, 27, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 27, 27, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 27, 27, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 27, 27, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 14, 14, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 14, 14, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 14, 14, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 14, 14, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 14, 14, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 14, 14, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 14, 14, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 14, 14, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 14, 14, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 14, 14, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 14, 14, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 14, 14, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 14, 14, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 14, 14, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 14, 14, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 14, 14, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 14, 14, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 14, 14, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 14, 14, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 14, 14, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 14, 14, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 14, 14, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 14, 14, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 14, 14, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 14, 14, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 14, 14, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 14, 14, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 14, 14, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 14, 14, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 14, 14, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 14, 14, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 14, 14, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 14, 14, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 14, 14, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 14, 14, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 14, 14, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 14, 14, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 14, 14, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 14, 14, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 14, 14, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 14, 14, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 14, 14, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 14, 14, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 7, 7, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, 7, 1024)   4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 7, 7, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 7, 7, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 7, 7, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 7, 7, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 7, 7, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 7, 7, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 7, 7, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 5)            10245       avg_pool[0][0]
# ==================================================================================================
# Total params: 20,871,725
# Trainable params: 20,817,197
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# Włączenie tensorboard.
# %tensorboard --logdir "/content/drive/My Drive/CNN_xception/logs"

# %%
history = model.fit(train_generator, 
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=validation_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=EPOCHS, shuffle=True,
                    callbacks=my_callbacks,
                    initial_epoch=INITIAL_EPOCH,
                    use_multiprocessing=False, verbose=1)
# Out:
# Epoch 1/50
# 701/701 [==============================] - 1268s 2s/step - loss: 0.2984 - accuracy: 0.8925 - val_loss: 0.2618 - val_accuracy: 0.9096
# Epoch 2/50
# 701/701 [==============================] - 1254s 2s/step - loss: 0.1451 - accuracy: 0.9494 - val_loss: 0.3808 - val_accuracy: 0.8951
# Epoch 3/50
# 701/701 [==============================] - 1263s 2s/step - loss: 0.1036 - accuracy: 0.9644 - val_loss: 0.2519 - val_accuracy: 0.9372
# Epoch 4/50
# 701/701 [==============================] - 1257s 2s/step - loss: 0.0807 - accuracy: 0.9729 - val_loss: 0.1332 - val_accuracy: 0.9588
# Epoch 5/50
# 701/701 [==============================] - 1255s 2s/step - loss: 0.0630 - accuracy: 0.9787 - val_loss: 0.4590 - val_accuracy: 0.8575
# Epoch 6/50
# 701/701 [==============================] - 1254s 2s/step - loss: 0.0520 - accuracy: 0.9826 - val_loss: 0.2012 - val_accuracy: 0.9390
# Epoch 7/50
# 701/701 [==============================] - 1256s 2s/step - loss: 0.0475 - accuracy: 0.9833 - val_loss: 0.1103 - val_accuracy: 0.9701
# Epoch 8/50
# 701/701 [==============================] - 1252s 2s/step - loss: 0.0388 - accuracy: 0.9866 - val_loss: 0.2897 - val_accuracy: 0.8974
# Epoch 9/50
# 701/701 [==============================] - 1255s 2s/step - loss: 0.0329 - accuracy: 0.9890 - val_loss: 0.1862 - val_accuracy: 0.9544
# Epoch 10/50
#   3/701 [..............................] - ETA: 12:42 - loss: 0.0244 - accuracy: 0.9792
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f61033b933d8> in <module>()
#       6                     callbacks=my_callbacks,
#       7                     initial_epoch=INITIAL_EPOCH,
# ----> 8                     use_multiprocessing=False, verbose=1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# Sprawdzenie poprawności na danych testowych
test_generator.reset()
STEP_SIZE_TEST = test_generator.n // test_generator.batch_size 
scores = model.evaluate(test_generator, 
                        steps=STEP_SIZE_TEST,
                        verbose=0)
print(model.metrics_names[0] + '=', scores[0])
print(model.metrics_names[1] + '=', scores[1])

test_generator.reset()
probabilities = model.predict(test_generator, 
                              steps=STEP_SIZE_TEST,
                              verbose=0)
y_test = probabilities.argmax(axis=1)
y_pred = test_generator.classes
target_names = sorted(os.listdir(dir_path + "/test"))
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# loss= 0.12251509726047516
# accuracy= 0.970744252204895
#               precision    recall  f1-score   support
#
#       type_F       0.89      0.93      0.91       153
#       type_N       0.97      0.97      0.97      2414
#       type_Q       1.00      1.00      1.00      1604
#       type_S       0.93      0.88      0.91       643
#       type_V       0.96      0.99      0.98      1407
#
#     accuracy                           0.97      6221
#    macro avg       0.95      0.95      0.95      6221
# weighted avg       0.97      0.97      0.97      6221

# %%
# Trenowanie na danych ze zbioru walidacyjnego.
model.fit(validation_generator, 
          steps_per_epoch=STEP_SIZE_VALID,
        #   validation_data=validation_generator,
        #   validation_steps=STEP_SIZE_VALID,
          epochs=2, shuffle=True,
          use_multiprocessing=False, verbose=1)

# Sprawdzenie poprawności na danych testowych po trenowaniu na zbiorze walidacyjnym.
test_generator.reset()
STEP_SIZE_TEST = test_generator.n // test_generator.batch_size 
scores = model.evaluate(test_generator, 
                        steps=STEP_SIZE_TEST,
                        verbose=0)
print(model.metrics_names[0] + '=', scores[0])
print(model.metrics_names[1] + '=', scores[1])

test_generator.reset()
probabilities = model.predict(test_generator, 
                              steps=STEP_SIZE_TEST,
                              verbose=0)
y_test = probabilities.argmax(axis=1)
y_pred = test_generator.classes
target_names = sorted(os.listdir(dir_path + "/test"))
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Epoch 1/2
# 236/236 [==============================] - 386s 2s/step - loss: 0.0943 - accuracy: 0.9688
# Epoch 2/2
# 236/236 [==============================] - 385s 2s/step - loss: 0.0382 - accuracy: 0.9872
# loss= 0.24013987183570862
# accuracy= 0.9295933246612549
#               precision    recall  f1-score   support
#
#       type_F       0.98      0.55      0.71       284
#       type_N       0.91      0.97      0.94      2244
#       type_Q       1.00      0.90      0.95      1776
#       type_S       0.85      0.96      0.90       533
#       type_V       0.92      0.97      0.94      1384
#
#     accuracy                           0.93      6221
#    macro avg       0.93      0.87      0.89      6221
# weighted avg       0.93      0.93      0.93      6221

# %%
# Zapisanie pliku .csv porównując typ i predykcję, jest podane zdjęcie więc łatwo będzie sprawdzić co z nim nie tak
test_generator.reset()
probabilities = model.predict(test_generator, 
                              steps=STEP_SIZE_TEST,
                              verbose=1)
predicted_class_indices = np.argmax(probabilities, axis=1)
labels = (train_generator.class_indices)
labels = dict((v, k) for k, v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

filenames = test_generator.filenames
results=pd.DataFrame({"Filename": filenames,
                      "Predictions": predictions,})
results.to_csv("results.csv", sep=';', index=False)
# Out:
# 6221/6221 [==============================] - 171s 27ms/step

# %%
# Tworzenie schematu zawierającego kształt warstw.
from keras.utils import plot_model
plot_model(base_model, show_shapes=True, to_file="model.png")
