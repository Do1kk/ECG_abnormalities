# %%
# Before everything
from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(2)

from numpy import load
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import keras
from sklearn.metrics import classification_report
import numpy as np



numpy_file_dir = "drive/My Drive/NN_files/"
# load dict of arrays
X_train_test = load(numpy_file_dir + "X_train_test.npz")
y_train_test = load(numpy_file_dir + "y_train_test.npz")

# extract the first array
X_train_test = X_train_test["arr_0"]# jest typ uint8
y_train_test = y_train_test["arr_0"]
# check image shape
print(X_train_test.shape)
print(y_train_test.shape)




# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_train_test, y_train_test, test_size=0.2, shuffle= True) # random_state=42

# sprawdzić random state
# print(y_test[:10]) # [1 5 5 5 0 3 4 0 0 0] jest dobrze, cały czas daje takie same losowe dane

# one-hot encode target column
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# create model
model = Sequential()

# add model layers
# 64 - liczba neuronów, kernel_size - maska 3x3,
model.add(Conv2D(32, kernel_size=3, activation="relu", input_shape=(220, 220, 3), data_format="channels_last"))
model.add(Conv2D(32, kernel_size=5, activation="relu"))
model.add(Conv2D(32, kernel_size=3, activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, kernel_size=3, activation="relu"))
# model.add(Dropout(0.3)) # użycie gdy jest przeuczony, dużo więcej acc niż val_acc
model.add(Conv2D(32, kernel_size=3, activation="relu"))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(8, kernel_size=3, activation="relu"))
model.add(Conv2D(8, kernel_size=3, activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(8, kernel_size=3, activation="relu"))
model.add(Conv2D(16, kernel_size=3, activation="relu")) #
# model.add(Conv2D(8, kernel_size=3, activation="relu"))
# model.add(Conv2D(8, kernel_size=3, activation="relu"))
# model.add(Conv2D(8, kernel_size=3, activation="relu"))

# warstwa łącząca conv2d z warstwą dense
model.add(Flatten())
# liczba taka ile wyjść, tu 10 liczb (u mnie będzie 6 wyjść bo tyle jest typów)
model.add(Dense(6, activation="softmax"))
# Out:
# (15240, 220, 220, 3)
# (15240,)

# %%
# compile model using accuracy to measure model performance
model.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07), loss="categorical_crossentropy", metrics=["accuracy"]) # Adadelta, Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.999, amsgrad=False)

# train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=100, shuffle=True)
# Out:
# Train on 12192 samples, validate on 3048 samples
# Epoch 1/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 1.2214 - accuracy: 0.4934 - val_loss: 0.7414 - val_accuracy: 0.7159
# Epoch 2/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.6437 - accuracy: 0.7605 - val_loss: 0.5039 - val_accuracy: 0.8320
# Epoch 3/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.5122 - accuracy: 0.8246 - val_loss: 0.4726 - val_accuracy: 0.8317
# Epoch 4/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.4723 - accuracy: 0.8473 - val_loss: 0.4548 - val_accuracy: 0.8481
# Epoch 5/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.4414 - accuracy: 0.8542 - val_loss: 0.3961 - val_accuracy: 0.8763
# Epoch 6/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.4266 - accuracy: 0.8593 - val_loss: 0.4049 - val_accuracy: 0.8638
# Epoch 7/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3939 - accuracy: 0.8741 - val_loss: 0.3718 - val_accuracy: 0.8842
# Epoch 8/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3722 - accuracy: 0.8828 - val_loss: 0.3397 - val_accuracy: 0.8953
# Epoch 9/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3583 - accuracy: 0.8889 - val_loss: 0.3493 - val_accuracy: 0.8829
# Epoch 10/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3338 - accuracy: 0.8937 - val_loss: 0.3184 - val_accuracy: 0.9003
# Epoch 11/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3103 - accuracy: 0.9041 - val_loss: 0.2831 - val_accuracy: 0.9114
# Epoch 12/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2931 - accuracy: 0.9078 - val_loss: 0.2693 - val_accuracy: 0.9193
# Epoch 13/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2750 - accuracy: 0.9151 - val_loss: 0.2717 - val_accuracy: 0.9157
# Epoch 14/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2705 - accuracy: 0.9139 - val_loss: 0.3444 - val_accuracy: 0.8865
# Epoch 15/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2664 - accuracy: 0.9167 - val_loss: 0.2500 - val_accuracy: 0.9177
# Epoch 16/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2505 - accuracy: 0.9215 - val_loss: 0.2428 - val_accuracy: 0.9196
# Epoch 17/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2336 - accuracy: 0.9259 - val_loss: 0.2512 - val_accuracy: 0.9236
# Epoch 18/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2321 - accuracy: 0.9268 - val_loss: 0.2438 - val_accuracy: 0.9255
# Epoch 19/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2182 - accuracy: 0.9331 - val_loss: 0.2336 - val_accuracy: 0.9291
# Epoch 20/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2155 - accuracy: 0.9326 - val_loss: 0.2105 - val_accuracy: 0.9318
# Epoch 21/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1960 - accuracy: 0.9386 - val_loss: 0.2047 - val_accuracy: 0.9350
# Epoch 22/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1959 - accuracy: 0.9391 - val_loss: 0.2401 - val_accuracy: 0.9232
# Epoch 23/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1868 - accuracy: 0.9405 - val_loss: 0.1850 - val_accuracy: 0.9409
# Epoch 24/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1716 - accuracy: 0.9439 - val_loss: 0.1777 - val_accuracy: 0.9472
# Epoch 25/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1721 - accuracy: 0.9454 - val_loss: 0.1708 - val_accuracy: 0.9449
# Epoch 26/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1659 - accuracy: 0.9450 - val_loss: 0.1638 - val_accuracy: 0.9452
# Epoch 27/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1581 - accuracy: 0.9486 - val_loss: 0.1743 - val_accuracy: 0.9429
# Epoch 28/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1485 - accuracy: 0.9533 - val_loss: 0.1782 - val_accuracy: 0.9423
# Epoch 29/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1464 - accuracy: 0.9541 - val_loss: 0.1556 - val_accuracy: 0.9491
# Epoch 30/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1407 - accuracy: 0.9553 - val_loss: 0.1784 - val_accuracy: 0.9419
# Epoch 31/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1477 - accuracy: 0.9528 - val_loss: 0.1566 - val_accuracy: 0.9508
# Epoch 32/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1316 - accuracy: 0.9565 - val_loss: 0.1430 - val_accuracy: 0.9547
# Epoch 33/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1350 - accuracy: 0.9571 - val_loss: 0.1629 - val_accuracy: 0.9495
# Epoch 34/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1323 - accuracy: 0.9566 - val_loss: 0.1502 - val_accuracy: 0.9521
# Epoch 35/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1238 - accuracy: 0.9608 - val_loss: 0.1432 - val_accuracy: 0.9551
# Epoch 36/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1239 - accuracy: 0.9601 - val_loss: 0.1618 - val_accuracy: 0.9508
# Epoch 37/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1189 - accuracy: 0.9622 - val_loss: 0.1475 - val_accuracy: 0.9570
# Epoch 38/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1213 - accuracy: 0.9639 - val_loss: 0.1453 - val_accuracy: 0.9567
# Epoch 39/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1113 - accuracy: 0.9645 - val_loss: 0.1302 - val_accuracy: 0.9573
# Epoch 40/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1122 - accuracy: 0.9652 - val_loss: 0.1277 - val_accuracy: 0.9606
# Epoch 41/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1108 - accuracy: 0.9656 - val_loss: 0.1320 - val_accuracy: 0.9587
# Epoch 42/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1166 - accuracy: 0.9611 - val_loss: 0.1181 - val_accuracy: 0.9629
# Epoch 43/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1150 - accuracy: 0.9644 - val_loss: 0.1191 - val_accuracy: 0.9639
# Epoch 44/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1087 - accuracy: 0.9666 - val_loss: 0.1128 - val_accuracy: 0.9626
# Epoch 45/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1089 - accuracy: 0.9651 - val_loss: 0.1322 - val_accuracy: 0.9577
# Epoch 46/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1018 - accuracy: 0.9678 - val_loss: 0.1131 - val_accuracy: 0.9649
# Epoch 47/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1034 - accuracy: 0.9656 - val_loss: 0.1529 - val_accuracy: 0.9528
# Epoch 48/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1067 - accuracy: 0.9655 - val_loss: 0.1234 - val_accuracy: 0.9583
# Epoch 49/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0987 - accuracy: 0.9688 - val_loss: 0.1016 - val_accuracy: 0.9659
# Epoch 50/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0933 - accuracy: 0.9691 - val_loss: 0.1182 - val_accuracy: 0.9613
# Epoch 51/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0973 - accuracy: 0.9679 - val_loss: 0.1204 - val_accuracy: 0.9610
# Epoch 52/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0925 - accuracy: 0.9697 - val_loss: 0.1174 - val_accuracy: 0.9623
# Epoch 53/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0896 - accuracy: 0.9697 - val_loss: 0.1320 - val_accuracy: 0.9613
# Epoch 54/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0898 - accuracy: 0.9715 - val_loss: 0.1263 - val_accuracy: 0.9610
# Epoch 55/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0887 - accuracy: 0.9701 - val_loss: 0.1268 - val_accuracy: 0.9613
# Epoch 56/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0839 - accuracy: 0.9716 - val_loss: 0.1143 - val_accuracy: 0.9649
# Epoch 57/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0804 - accuracy: 0.9729 - val_loss: 0.1119 - val_accuracy: 0.9636
# Epoch 58/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0791 - accuracy: 0.9742 - val_loss: 0.1086 - val_accuracy: 0.9642
# Epoch 59/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0766 - accuracy: 0.9731 - val_loss: 0.1253 - val_accuracy: 0.9570
# Epoch 60/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0784 - accuracy: 0.9756 - val_loss: 0.0989 - val_accuracy: 0.9711
# Epoch 61/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0710 - accuracy: 0.9762 - val_loss: 0.1169 - val_accuracy: 0.9633
# Epoch 62/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0763 - accuracy: 0.9747 - val_loss: 0.1023 - val_accuracy: 0.9633
# Epoch 63/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0639 - accuracy: 0.9792 - val_loss: 0.1011 - val_accuracy: 0.9701
# Epoch 64/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0723 - accuracy: 0.9758 - val_loss: 0.1154 - val_accuracy: 0.9636
# Epoch 65/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0663 - accuracy: 0.9781 - val_loss: 0.1042 - val_accuracy: 0.9675
# Epoch 66/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0652 - accuracy: 0.9783 - val_loss: 0.1449 - val_accuracy: 0.9560
# Epoch 67/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0681 - accuracy: 0.9770 - val_loss: 0.1028 - val_accuracy: 0.9675
# Epoch 68/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0613 - accuracy: 0.9788 - val_loss: 0.0994 - val_accuracy: 0.9682
# Epoch 69/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0601 - accuracy: 0.9797 - val_loss: 0.1044 - val_accuracy: 0.9646
# Epoch 70/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0557 - accuracy: 0.9807 - val_loss: 0.1030 - val_accuracy: 0.9678
# Epoch 71/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0558 - accuracy: 0.9809 - val_loss: 0.0928 - val_accuracy: 0.9698
# Epoch 72/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0510 - accuracy: 0.9823 - val_loss: 0.1167 - val_accuracy: 0.9652
# Epoch 73/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0566 - accuracy: 0.9816 - val_loss: 0.1046 - val_accuracy: 0.9698
# Epoch 74/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0499 - accuracy: 0.9822 - val_loss: 0.0928 - val_accuracy: 0.9728
# Epoch 75/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0512 - accuracy: 0.9840 - val_loss: 0.0940 - val_accuracy: 0.9718
# Epoch 76/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0507 - accuracy: 0.9836 - val_loss: 0.0944 - val_accuracy: 0.9731
# Epoch 77/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0486 - accuracy: 0.9841 - val_loss: 0.1189 - val_accuracy: 0.9656
# Epoch 78/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0446 - accuracy: 0.9857 - val_loss: 0.0984 - val_accuracy: 0.9721
# Epoch 79/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0433 - accuracy: 0.9848 - val_loss: 0.0999 - val_accuracy: 0.9718
# Epoch 80/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0488 - accuracy: 0.9831 - val_loss: 0.0899 - val_accuracy: 0.9744
# Epoch 81/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0465 - accuracy: 0.9844 - val_loss: 0.0926 - val_accuracy: 0.9724
# Epoch 82/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0452 - accuracy: 0.9846 - val_loss: 0.1027 - val_accuracy: 0.9734
# Epoch 83/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0463 - accuracy: 0.9843 - val_loss: 0.1037 - val_accuracy: 0.9685
# Epoch 84/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0435 - accuracy: 0.9859 - val_loss: 0.1052 - val_accuracy: 0.9731
# Epoch 85/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0414 - accuracy: 0.9861 - val_loss: 0.1011 - val_accuracy: 0.9741
# Epoch 86/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0428 - accuracy: 0.9856 - val_loss: 0.1098 - val_accuracy: 0.9724
# Epoch 87/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0387 - accuracy: 0.9875 - val_loss: 0.0975 - val_accuracy: 0.9757
# Epoch 88/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0362 - accuracy: 0.9878 - val_loss: 0.1170 - val_accuracy: 0.9656
# Epoch 89/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0374 - accuracy: 0.9872 - val_loss: 0.1105 - val_accuracy: 0.9721
# Epoch 90/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0362 - accuracy: 0.9880 - val_loss: 0.0975 - val_accuracy: 0.9744
# Epoch 91/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0377 - accuracy: 0.9874 - val_loss: 0.1032 - val_accuracy: 0.9711
# Epoch 92/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.1082 - val_accuracy: 0.9738
# Epoch 93/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0290 - accuracy: 0.9897 - val_loss: 0.1057 - val_accuracy: 0.9757
# Epoch 94/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0410 - accuracy: 0.9856 - val_loss: 0.1219 - val_accuracy: 0.9678
# Epoch 95/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0326 - accuracy: 0.9889 - val_loss: 0.1083 - val_accuracy: 0.9711
# Epoch 96/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0411 - accuracy: 0.9853 - val_loss: 0.0938 - val_accuracy: 0.9774
# Epoch 97/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 0.0994 - val_accuracy: 0.9731
# Epoch 98/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.1203 - val_accuracy: 0.9724
# Epoch 99/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0360 - accuracy: 0.9878 - val_loss: 0.1115 - val_accuracy: 0.9669
# Epoch 100/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0329 - accuracy: 0.9885 - val_loss: 0.0944 - val_accuracy: 0.9787

# %%
Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(X_test)
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       526
#            1       1.00      0.99      1.00       497
#            2       0.98      0.99      0.98       484
#            3       0.94      0.95      0.95       506
#            4       0.97      0.97      0.97       501
#            5       1.00      1.00      1.00       534
#
#     accuracy                           0.98      3048
#    macro avg       0.98      0.98      0.98      3048
# weighted avg       0.98      0.98      0.98      3048

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
