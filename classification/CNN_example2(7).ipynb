# %%
# Before everything
from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(2)

from numpy import load
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import keras
from sklearn.metrics import classification_report
import numpy as np



numpy_file_dir = "drive/My Drive/NN_files/"
# load dict of arrays
X_train_test = load(numpy_file_dir + "X_train_test.npz")
y_train_test = load(numpy_file_dir + "y_train_test.npz")

# extract the first array
X_train_test = X_train_test["arr_0"]# jest typ uint8
y_train_test = y_train_test["arr_0"]
# check image shape
print(X_train_test.shape)
print(y_train_test.shape)




# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_train_test, y_train_test, test_size=0.2, shuffle= True) # random_state=42

# sprawdzić random state
# print(y_test[:10]) # [1 5 5 5 0 3 4 0 0 0] jest dobrze, cały czas daje takie same losowe dane

# one-hot encode target column
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# create model
model = Sequential()

# add model layers
# 64 - liczba neuronów, kernel_size - maska 3x3,
model.add(Conv2D(32, kernel_size=3, activation="relu", input_shape=(220, 220, 3), data_format="channels_last"))
model.add(Conv2D(32, kernel_size=5, activation="relu"))
model.add(Conv2D(32, kernel_size=3, activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, kernel_size=3, activation="relu"))
# model.add(Dropout(0.3)) # użycie gdy jest przeuczony, dużo więcej acc niż val_acc
model.add(Conv2D(32, kernel_size=3, activation="relu"))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(Conv2D(16, kernel_size=3, activation="relu"))
model.add(Conv2D(8, kernel_size=3, activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(8, kernel_size=3, activation="relu"))
model.add(Conv2D(8, kernel_size=3, activation="relu"))
# model.add(Conv2D(8, kernel_size=3, activation="relu"))
# model.add(Conv2D(8, kernel_size=3, activation="relu"))
# model.add(Conv2D(8, kernel_size=3, activation="relu"))
# model.add(Conv2D(8, kernel_size=3, activation="relu"))

# warstwa łącząca conv2d z warstwą dense
model.add(Flatten())
# liczba taka ile wyjść, tu 10 liczb (u mnie będzie 6 wyjść bo tyle jest typów)
model.add(Dense(6, activation="softmax"))
# Out:
# (15240, 220, 220, 3)
# (15240,)

# %%
# compile model using accuracy to measure model performance
model.compile(optimizer=keras.optimizers.Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07), loss="categorical_crossentropy", metrics=["accuracy"]) #  Adadelta, Adam(learning_rate=0.005, beta_1=0.9, beta_2=0.999, amsgrad=False)

# train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=100, shuffle=True)
# Out:
# Train on 12192 samples, validate on 3048 samples
# Epoch 1/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.9604 - accuracy: 0.5993 - val_loss: 0.4811 - val_accuracy: 0.8422
# Epoch 2/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.4435 - accuracy: 0.8569 - val_loss: 0.4055 - val_accuracy: 0.8665
# Epoch 3/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3677 - accuracy: 0.8775 - val_loss: 0.3702 - val_accuracy: 0.8720
# Epoch 4/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3373 - accuracy: 0.8894 - val_loss: 0.3323 - val_accuracy: 0.8934
# Epoch 5/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.3140 - accuracy: 0.8960 - val_loss: 0.2902 - val_accuracy: 0.9052
# Epoch 6/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2900 - accuracy: 0.9019 - val_loss: 0.3304 - val_accuracy: 0.8865
# Epoch 7/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2802 - accuracy: 0.9040 - val_loss: 0.2850 - val_accuracy: 0.9072
# Epoch 8/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2490 - accuracy: 0.9179 - val_loss: 0.2492 - val_accuracy: 0.9193
# Epoch 9/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2326 - accuracy: 0.9232 - val_loss: 0.2545 - val_accuracy: 0.9173
# Epoch 10/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2314 - accuracy: 0.9247 - val_loss: 0.2571 - val_accuracy: 0.9150
# Epoch 11/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2239 - accuracy: 0.9271 - val_loss: 0.2628 - val_accuracy: 0.9144
# Epoch 12/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2149 - accuracy: 0.9297 - val_loss: 0.2004 - val_accuracy: 0.9370
# Epoch 13/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.2026 - accuracy: 0.9345 - val_loss: 0.2228 - val_accuracy: 0.9334
# Epoch 14/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1920 - accuracy: 0.9395 - val_loss: 0.2131 - val_accuracy: 0.9327
# Epoch 15/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1943 - accuracy: 0.9372 - val_loss: 0.1877 - val_accuracy: 0.9439
# Epoch 16/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1898 - accuracy: 0.9395 - val_loss: 0.2037 - val_accuracy: 0.9311
# Epoch 17/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1695 - accuracy: 0.9481 - val_loss: 0.1820 - val_accuracy: 0.9419
# Epoch 18/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1644 - accuracy: 0.9491 - val_loss: 0.1859 - val_accuracy: 0.9419
# Epoch 19/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1579 - accuracy: 0.9508 - val_loss: 0.2004 - val_accuracy: 0.9360
# Epoch 20/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1552 - accuracy: 0.9515 - val_loss: 0.2269 - val_accuracy: 0.9337
# Epoch 21/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1530 - accuracy: 0.9523 - val_loss: 0.1730 - val_accuracy: 0.9472
# Epoch 22/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1384 - accuracy: 0.9542 - val_loss: 0.1677 - val_accuracy: 0.9488
# Epoch 23/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1392 - accuracy: 0.9546 - val_loss: 0.1756 - val_accuracy: 0.9459
# Epoch 24/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1318 - accuracy: 0.9584 - val_loss: 0.1573 - val_accuracy: 0.9488
# Epoch 25/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1354 - accuracy: 0.9576 - val_loss: 0.1626 - val_accuracy: 0.9485
# Epoch 26/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1243 - accuracy: 0.9590 - val_loss: 0.1461 - val_accuracy: 0.9560
# Epoch 27/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1328 - accuracy: 0.9589 - val_loss: 0.1688 - val_accuracy: 0.9429
# Epoch 28/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1223 - accuracy: 0.9618 - val_loss: 0.1607 - val_accuracy: 0.9511
# Epoch 29/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1192 - accuracy: 0.9623 - val_loss: 0.1448 - val_accuracy: 0.9570
# Epoch 30/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1159 - accuracy: 0.9644 - val_loss: 0.1594 - val_accuracy: 0.9498
# Epoch 31/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1116 - accuracy: 0.9657 - val_loss: 0.1398 - val_accuracy: 0.9570
# Epoch 32/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1093 - accuracy: 0.9660 - val_loss: 0.1370 - val_accuracy: 0.9564
# Epoch 33/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1053 - accuracy: 0.9679 - val_loss: 0.1354 - val_accuracy: 0.9600
# Epoch 34/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1117 - accuracy: 0.9636 - val_loss: 0.1595 - val_accuracy: 0.9465
# Epoch 35/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1042 - accuracy: 0.9679 - val_loss: 0.1497 - val_accuracy: 0.9541
# Epoch 36/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.1041 - accuracy: 0.9680 - val_loss: 0.1350 - val_accuracy: 0.9600
# Epoch 37/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0933 - accuracy: 0.9698 - val_loss: 0.1896 - val_accuracy: 0.9524
# Epoch 38/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0980 - accuracy: 0.9692 - val_loss: 0.1489 - val_accuracy: 0.9593
# Epoch 39/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0955 - accuracy: 0.9703 - val_loss: 0.1446 - val_accuracy: 0.9557
# Epoch 40/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0942 - accuracy: 0.9718 - val_loss: 0.1615 - val_accuracy: 0.9531
# Epoch 41/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0912 - accuracy: 0.9713 - val_loss: 0.1789 - val_accuracy: 0.9495
# Epoch 42/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0960 - accuracy: 0.9696 - val_loss: 0.1475 - val_accuracy: 0.9531
# Epoch 43/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0893 - accuracy: 0.9712 - val_loss: 0.1341 - val_accuracy: 0.9613
# Epoch 44/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0877 - accuracy: 0.9724 - val_loss: 0.1539 - val_accuracy: 0.9528
# Epoch 45/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0861 - accuracy: 0.9728 - val_loss: 0.1375 - val_accuracy: 0.9610
# Epoch 46/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0893 - accuracy: 0.9732 - val_loss: 0.1400 - val_accuracy: 0.9570
# Epoch 47/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0791 - accuracy: 0.9756 - val_loss: 0.1385 - val_accuracy: 0.9613
# Epoch 48/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0857 - accuracy: 0.9726 - val_loss: 0.1439 - val_accuracy: 0.9603
# Epoch 49/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0791 - accuracy: 0.9762 - val_loss: 0.1339 - val_accuracy: 0.9596
# Epoch 50/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0809 - accuracy: 0.9755 - val_loss: 0.1569 - val_accuracy: 0.9547
# Epoch 51/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0839 - accuracy: 0.9729 - val_loss: 0.1675 - val_accuracy: 0.9531
# Epoch 52/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0837 - accuracy: 0.9746 - val_loss: 0.1221 - val_accuracy: 0.9633
# Epoch 53/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0724 - accuracy: 0.9765 - val_loss: 0.1364 - val_accuracy: 0.9593
# Epoch 54/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0695 - accuracy: 0.9776 - val_loss: 0.1355 - val_accuracy: 0.9610
# Epoch 55/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0767 - accuracy: 0.9746 - val_loss: 0.1463 - val_accuracy: 0.9610
# Epoch 56/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0742 - accuracy: 0.9766 - val_loss: 0.1259 - val_accuracy: 0.9636
# Epoch 57/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0752 - accuracy: 0.9753 - val_loss: 0.1665 - val_accuracy: 0.9560
# Epoch 58/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0685 - accuracy: 0.9792 - val_loss: 0.1465 - val_accuracy: 0.9593
# Epoch 59/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0644 - accuracy: 0.9782 - val_loss: 0.1387 - val_accuracy: 0.9636
# Epoch 60/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0760 - accuracy: 0.9754 - val_loss: 0.1417 - val_accuracy: 0.9613
# Epoch 61/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0678 - accuracy: 0.9788 - val_loss: 0.1489 - val_accuracy: 0.9554
# Epoch 62/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0705 - accuracy: 0.9779 - val_loss: 0.1693 - val_accuracy: 0.9554
# Epoch 63/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0643 - accuracy: 0.9784 - val_loss: 0.1609 - val_accuracy: 0.9554
# Epoch 64/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0650 - accuracy: 0.9785 - val_loss: 0.1388 - val_accuracy: 0.9665
# Epoch 65/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0651 - accuracy: 0.9792 - val_loss: 0.1790 - val_accuracy: 0.9478
# Epoch 66/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0613 - accuracy: 0.9800 - val_loss: 0.1309 - val_accuracy: 0.9662
# Epoch 67/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0679 - accuracy: 0.9776 - val_loss: 0.1353 - val_accuracy: 0.9623
# Epoch 68/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0571 - accuracy: 0.9815 - val_loss: 0.1562 - val_accuracy: 0.9590
# Epoch 69/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0618 - accuracy: 0.9809 - val_loss: 0.1320 - val_accuracy: 0.9619
# Epoch 70/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0678 - accuracy: 0.9774 - val_loss: 0.1304 - val_accuracy: 0.9669
# Epoch 71/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0602 - accuracy: 0.9813 - val_loss: 0.1549 - val_accuracy: 0.9554
# Epoch 72/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0620 - accuracy: 0.9808 - val_loss: 0.1382 - val_accuracy: 0.9626
# Epoch 73/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0618 - accuracy: 0.9797 - val_loss: 0.1401 - val_accuracy: 0.9649
# Epoch 74/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0556 - accuracy: 0.9819 - val_loss: 0.1399 - val_accuracy: 0.9606
# Epoch 75/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0567 - accuracy: 0.9815 - val_loss: 0.1440 - val_accuracy: 0.9573
# Epoch 76/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0549 - accuracy: 0.9812 - val_loss: 0.1555 - val_accuracy: 0.9639
# Epoch 77/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0600 - accuracy: 0.9803 - val_loss: 0.1337 - val_accuracy: 0.9659
# Epoch 78/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0489 - accuracy: 0.9832 - val_loss: 0.1458 - val_accuracy: 0.9659
# Epoch 79/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0493 - accuracy: 0.9851 - val_loss: 0.1533 - val_accuracy: 0.9590
# Epoch 80/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0634 - accuracy: 0.9791 - val_loss: 0.1550 - val_accuracy: 0.9570
# Epoch 81/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0452 - accuracy: 0.9851 - val_loss: 0.1473 - val_accuracy: 0.9649
# Epoch 82/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0500 - accuracy: 0.9825 - val_loss: 0.1366 - val_accuracy: 0.9636
# Epoch 83/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0536 - accuracy: 0.9821 - val_loss: 0.1339 - val_accuracy: 0.9675
# Epoch 84/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0495 - accuracy: 0.9832 - val_loss: 0.1682 - val_accuracy: 0.9577
# Epoch 85/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0450 - accuracy: 0.9842 - val_loss: 0.1578 - val_accuracy: 0.9649
# Epoch 86/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0416 - accuracy: 0.9852 - val_loss: 0.1476 - val_accuracy: 0.9610
# Epoch 87/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0407 - accuracy: 0.9865 - val_loss: 0.1511 - val_accuracy: 0.9629
# Epoch 88/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.1557 - val_accuracy: 0.9636
# Epoch 89/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0511 - accuracy: 0.9829 - val_loss: 0.1342 - val_accuracy: 0.9678
# Epoch 90/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0418 - accuracy: 0.9865 - val_loss: 0.1306 - val_accuracy: 0.9675
# Epoch 91/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0381 - accuracy: 0.9865 - val_loss: 0.1708 - val_accuracy: 0.9619
# Epoch 92/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0530 - accuracy: 0.9820 - val_loss: 0.1412 - val_accuracy: 0.9646
# Epoch 93/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0384 - accuracy: 0.9872 - val_loss: 0.1605 - val_accuracy: 0.9642
# Epoch 94/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0429 - accuracy: 0.9848 - val_loss: 0.1459 - val_accuracy: 0.9672
# Epoch 95/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0404 - accuracy: 0.9856 - val_loss: 0.1585 - val_accuracy: 0.9656
# Epoch 96/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0427 - accuracy: 0.9861 - val_loss: 0.1727 - val_accuracy: 0.9603
# Epoch 97/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0391 - accuracy: 0.9870 - val_loss: 0.1508 - val_accuracy: 0.9652
# Epoch 98/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0384 - accuracy: 0.9868 - val_loss: 0.1726 - val_accuracy: 0.9544
# Epoch 99/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0383 - accuracy: 0.9867 - val_loss: 0.1725 - val_accuracy: 0.9656
# Epoch 100/100
# 12192/12192 [==============================] - 30s 2ms/step - loss: 0.0431 - accuracy: 0.9835 - val_loss: 0.1497 - val_accuracy: 0.9636

# %%
Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(X_test)
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       526
#            1       0.99      0.99      0.99       497
#            2       0.95      0.98      0.97       484
#            3       0.94      0.88      0.91       506
#            4       0.98      0.95      0.96       501
#            5       1.00      1.00      1.00       534
#
#     accuracy                           0.96      3048
#    macro avg       0.96      0.96      0.96      3048
# weighted avg       0.96      0.96      0.96      3048

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
